# %% [markdown]
# # **Preliminary: Install and Import Packages**

# %%
# !pip install kaggle
import os


os.environ['KAGGLE_USERNAME'] = 'zn2222'
os.environ['KAGGLE_KEY'] = '5cb10e85beb74201628848dbe07b4874'

# %% [markdown]
# # **Query Data**

# %% [markdown]
# Query Data from the Source:
# https://www.kaggle.com/datasets/konradb/gpt4-the-tweets

# %%
# !kaggle datasets download -d konradb/gpt4-the-tweets
# !unzip gpt4-the-tweets.zip
# Out:
# ...
#   0% 0.00/3.43M [00:00<?, ?B/s]
# 100% 3.43M/3.43M [00:00<00:00, 43.1MB/s]
# Archive:  gpt4-the-tweets.zip
#   inflating: tweets.csv

# %%
import pandas as pd

df = pd.read_csv('tweets.csv')

df.head()
# Out:
#                         date  \
# 0  2023-04-12 20:05:08+00:00
# 1  2023-04-12 20:05:06+00:00
# 2  2023-04-12 20:05:04+00:00
# 3  2023-04-12 20:05:02+00:00
# 4  2023-04-12 20:04:58+00:00
#
#                                                 text user_name user_location  \
# 0  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Join ...     fuari    Cyberspace
# 1  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Inves...     fuari    Cyberspace
# 2  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Get r...     fuari    Cyberspace
# 3  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Want ...     fuari    Cyberspace
# 4  @100xAltcoinGems $NEURONI\n\n Discover the lat...     fuari    Cyberspace
#
#      user_description               user_created  user_followers  \
# 0  beautiful together  2022-12-27 16:50:49+00:00              57
# 1  beautiful together  2022-12-27 16:50:49+00:00              57
# 2  beautiful together  2022-12-27 16:50:49+00:00              57
# ...

# %% [markdown]
# # **Inspect Data**

# %%
df.head(10)
# Out:
#                         date  \
# 0  2023-04-12 20:05:08+00:00
# 1  2023-04-12 20:05:06+00:00
# 2  2023-04-12 20:05:04+00:00
# 3  2023-04-12 20:05:02+00:00
# 4  2023-04-12 20:04:58+00:00
# 5  2023-04-12 20:04:58+00:00
# 6  2023-04-12 20:04:46+00:00
# 7  2023-04-12 20:04:44+00:00
# 8  2023-04-12 20:04:42+00:00
# 9  2023-04-12 20:04:40+00:00
#
#                                                 text       user_name  \
# 0  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Join ...           fuari
# 1  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Inves...           fuari
# 2  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Get r...           fuari
# 3  @100xAltcoinGems @NeuroniAI $NEURONI\n\n Want ...           fuari
# 4  @100xAltcoinGems $NEURONI\n\n Discover the lat...           fuari
# 5  You can earn thousands of 💰💰💰 using these AI.....  Kubode Raymond
# 6  @DaCryptoCom @NeuroniAI $NEURONI\n\n Need code...           fuari
# 7  @DaCryptoCom @NeuroniAI $NEURONI\n\n When ther...           fuari
# ...

# %%
df.tail()
# Out:
#                             date  \
# 28705  2023-03-14 13:18:03+00:00
# 28706  2023-03-14 13:03:11+00:00
# 28707  2023-03-14 12:45:23+00:00
# 28708  2023-03-14 12:40:07+00:00
# 28709  2023-03-14 12:37:17+00:00
#
#                                                     text     user_name  \
# 28705  #gpt4 also #brootswasright https://t.co/tMTUiN...   Clone ❌ God
# 28706  How much energy does it take to train #GPT4, t...       Adam Ai
# 28707  It looks like VIDEO is dominating the GPT-4 po...     Intercept
# 28708  The perfect storm is brewing, with the upcomin...         Dante
# 28709  On the horizon - #GPT4 and why it matters. | T...  MohitRajhans
#
#           user_location                                   user_description  \
# 28705               NaN  kawaii skulls are the most original Japanese p...
# 28706               NaN  Exploring the future of human-AI conversation ...
# 28707  Toronto, Ontario  B2B marketing agency helping global technology...
# ...

# %%
df.dtypes
# Out:
# date                object
# text                object
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# hashtags            object
# source              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28710 entries, 0 to 28709
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              28710 non-null  object
#  1   text              28710 non-null  object
#  2   user_name         28709 non-null  object
#  3   user_location     13683 non-null  object
#  4   user_description  17377 non-null  object
#  5   user_created      28710 non-null  object
#  6   user_followers    28710 non-null  int64
#  7   user_friends      28710 non-null  int64
#  8   user_favourites   28710 non-null  int64
#  9   user_verified     28710 non-null  bool
#  10  hashtags          23476 non-null  object
#  11  source            28710 non-null  object
# dtypes: bool(1), int64(3), object(8)
# memory usage: 2.4+ MB

# %% [markdown]
# # **Output Data**

# %%
df.to_csv('tweets_data.csv', index=False)
